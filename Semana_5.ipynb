# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelmgr12/UNIVESP-AlgeProg2/blob/master/Semana_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Semana 5

# %% [markdown]
# ## Ordenação

# %% [markdown]
# Ordenação é largamente utilizada
# - Listas telefônicas e dicionários
# - Grandes sistemas de BD e processamento de
# dados
# - Etc.
#
# Algoritmos de ordenação são ilustrativos
# - Como resolver problemas computacionais
# - Como lidar com estruturas de dados
# - Como desenvolver algoritmos elegantes e como
# analisar e comparar seus desempenhos

# %% [markdown]
# Definição: organizar uma sequência de
# elementos de modo que os mesmos
# estabeleçam alguma relação de ordem.
#
# Diz-se que os elementos $k_1, ..., k_n$ estarão dispostos de modo que $k_1\leq k_2\leq\dots\leq k_n$

# %% [markdown]
# Ocasionalmente, dá menos trabalho buscar um
# elemento em um conjunto desordenado do que
# ordenar primeiro e depois buscar.
#
# Por outro lado, se a busca for uma operação
# frequente, vale a pena ordenar (pode ser feita
# apenas uma vez).
#
# **Depende das circunstâncias!**

# %% [markdown]
# ### Bublle sort

# %% [markdown]
# Um dos métodos mais conhecido e intuitivos.
#
# Ideia básica:
# - Percorrrer o conjunto várias vezes
# - A cada iteração, compara cada eleento com seu sucessor ( v[i] com v[i+1] e trocá-los de lugar caso estejam na ordem incorreta.

# %% [markdown]
# **Passo 1**
#
# • Vetor inicial
#
#     • X = (25 , 57 , 48 , 37 , 12 , 92 , 86 , 33)
#
# • X[0] com X[1] (25 com 57) não ocorre permutação
#
#     • X = (25 , 57 , 48 , 37 , 12 , 92 , 86 , 33)
#
# • X[1] com X[2] (57 com 48) ocorre permutação
#
#     • X = (25 , 48 , 57 , 37 , 12 , 92 , 86 , 33)
#
# • X[2] com X[3] (57 com 37) ocorre permutação
#
#     • X = (25 , 48 , 37 , 57 , 12 , 92 , 86 , 33)
#
# • X[3] com X[4] (57 com 12) ocorre permutação
#
#     • X = (25 , 48 , 37 , 12 , 57 , 92 , 86 , 33)
#
# • X[4] com X[5] (57 com 92) não ocorre permutação
#
#     • X = (25 , 48 , 37 , 12 , 57 , 92 , 86 , 33)
#
# • X[5] com X[6] (92 com 86) ocorre permutação
#
#     • X = (25 , 48 , 37 , 12 , 57 , 86 , 92 , 33)
#
# • X[6] com X[7] (92 com 33) ocorre permutação
#     • X = (25 , 48 , 37 , 12 , 57 , 86 , 33 , 92)

# %% [markdown]
# ** Passo 2**
# • Vetor após passo 1
#
#     • X = (25 , 48 , 37 , 12 , 57 , 86 , 33 , 92)
#
# • X[0] com X[1] (25 com 48) não ocorre permutação
#
#     • X = (25 , 48 , 37 , 12 , 57 , 86 , 33 , 92)
#
# • X[1] com X[2] (48 com 37) ocorre permutação
#
#     • X = (25 , 37 , 48 , 12 , 57 , 86 , 33 , 92)
#
# • X[2] com X[3] (48 com 12) ocorre permutação
#
#     • X = (25 , 37 , 12 , 48 , 57 , 86 , 33 , 92)
#
# • X[3] com X[4] (48 com 57) não ocorre permutação
#
#     • X = (25 , 37 , 12 , 48 , 57 , 86 , 33 , 92)
#
# • X[4] com X[5] (57 com 86) não ocorre permutação
#
#     • X = (25 , 37 , 12 , 48 , 57 , 86 , 33 , 92)
#
# • X[5] com X[6] (86 com 33) ocorre permutação
#
#     • X = (25 , 37 , 12 , 48 , 57 , 33 , 86 , 92)
#
# • X[6] com X[7] (86 com 92) não ocorre permutação
#
#     • X = (25 , 37 , 12 , 48 , 57 , 33 , 86 , 92)

# %% [markdown]
# Depois do primeiro passo
# - Vetor: (24, 48, 37, 12, 57, 86, 33, 92)
# - O maior elemento (92) está na posição correta
#
# Para um vetor de n elementos, são necessárias
# n-1 iterações.
#
# A cada iteração, os elementos vão assumindo
# suas posições corretas.

# %% [markdown]
# Implementação em Python

# %%
def buble_sort(v):
  for i in range(len(v)-1):
    for j in range(len(v)-i-1):
      if v[j]>v[j+1]:
        v[j], v[j+1] = v[j+1], v[j]

v = [1,5,6,8,9,4,2,3,4]
buble_sort(v)
v

# %% [markdown]
# ### Insertion Sort

# %% [markdown]
# Ideia básica:
#
# - Ordenar o conjunto inserindo os elementos
# em um subconjunto já ordenado.
# - No i-ésimo passo, inserir o i-ésimo elemento
# na posição correta entre x[0], ..., x[i-1], que já
# estão em ordem.
#   - Realocar elementos

# %% [markdown]
# ![Captura de tela de 2020-11-04 14-25-00.png](data:image/png;base64,...)

# %% [markdown]
# • X = (44 , 55 , 12 , 42 , 94 , 18 , 06 , 67)
#
# • passo 1 (55) 44 55 12 42 94 18 06 67
#
# • passo 2 (12) 12 44 55 42 94 18 06 67
#
# • passo 3 (42) 12 42 44 55 94 18 06 67
#
# • passo 4 (94) 12 42 44 55 94 18 06 67
#
# • passo 5 (18) 12 18 42 44 55 94 06 67
#
# • passo 6 (06) 06 12 18 42 44 55 94 67
#
# • passo 7 (67) 06 12 18 42 44 55 67 94

# %% [markdown]
# Implementaçào em python

# %%
def insertion_sort(v):
  for i in range(1,len(v)):
    x = v[i]
    j = i-1
    while j>= 0 and x<v[j]:
      v[j+1] = v[j]
      j-=1
      v[j+1] = x

v = [1,5,6,8,9,4,2,3,7]
insertion_sort(v)
v

# %% [markdown]
# ### Merge sort

# %% [markdown]
# Também chamado de ordenação por
# intercalação.
#
# Ideia básica: dividir para conquistar
# - Um vetor v é dividido em duas partes,
# recursivamente.
# - Cada metade é ordenada e ambas são
# intercaladas formando o vetor ordenado.
# - Usa um vetor auxiliar para intercalar.

# %% [markdown]
# Observe a figura

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-17-05.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-17-17.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-17-39.png](data:image/png;base64,...)

# %% [markdown]
# Implementação em Python

# %%
def merge_sort(v,ini,fim):
  if ini < fim:
    meio = (ini + fim)//2
    merge_sort(v, ini, meio)
    merge_sort(v, meio+1,fim)
    intercala(v, ini, meio,fim)
def intercala(v,ini,meio,fim):
  L = v[ini:meio+1]
  R = v[meio+1:fim+1]
  L.append(999) #sentinela
  R.append(999) #sentinela
  i = 0
  j = 0
  for k in range(ini, fim+1):
    if L[i] <= R[j]:
      v[k] = L[i]
      i += 1
    else:
      v[k] = R[j]
      j += 1

v = [1,5,6,8,9,4,2,3,7]
merge_sort(v,0,len(v)-1)
v

# %% [markdown]
# ### Quicksort

# %% [markdown]
# Algoritmo também baseado na estratégia
# dividir para conquistar.
#
# Ideia básica:
# - Dividir o vetor em dois vetores menores que
# serão ordenados independentemente e
# combinados para produzir o resultado final.

# %% [markdown]
# Primeiro passo
#
# Escolha de um elemento pivô x, colocando-o
# em sua posição correta
# - Ordenar de forma que os elementos à esquerda
# do pivô são menores ou iguais a ele e os
# elementos à direita são maiores ou iguais a ele
# - Percorrer o vetor v da esquerda para direita até v[i] >=
# x; e da direita para esquerda até que v[j] <= x.
# - Trocar v[i] com v[j], incrementar i, decrementar j
# - Quando i e j se cruzarem, a iteração finaliza, de forma
# que v[0]...v[j] são menores ou iguais a x e v[i]...v[n-1]
# são maiores ou iguais a x

# %% [markdown]
# Segundo Passo
#
# Ordenar subvetores à esquerda e à direita do
# elemento pivô.

# %% [markdown]
# **Exemplo**
#
# 25 57 35 37 12 86 92 33

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-27-20.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-27-34.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-27-48.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-27-59.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-28-15.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-28-26.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-28-38.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-28-54.png](data:image/png;base64,...)

# %% [markdown]
# **Exercício**
#
# Fazer as ordenações dos subvetores,
# repetindo o processo
#
# 25 33 35 12 37 86 92 57

# %% [markdown]
# **Reposta**

# %% [markdown]
# Implementação em Python

# %%
def quick_sort(v, ini, fim):
  meio = (ini + fim) // 2
  pivo = v[meio]
  i = ini
  j = fim
  while i < j:
    while v[i] < pivo:
      i+= 1
    while v[j] > pivo:
      j -= 1
    if i <= j:
      v[i], v[j] = v[j], v[i]
    i += 1
    j -= 1
    if j > ini:
      quick_sort(v, ini, j)
    if i < fim:
      quick_sort(v, i, fim)

v = [1,5,6,8,9,4,2,3,7]
quick_sort(v,0,len(v)-1)
v

# %% [markdown]
# ### Heap Sort

# %% [markdown]
# Utiliza uma estrutura heap
# para ordenar os elementos.
# Um heap é uma estrutura
# de dados em que há uma
# ordenação dos elementos:
# representação via árvore
# binária.
#
# ![Captura de tela de 2020-11-04 15-33-49.png](data:image/png;base64,...)

# %% [markdown]
# Um heap observa conceitos de ordem e de
# forma.
# - Ordem: o item de qualquer nó deve satisfazer
# uma relação de ordem com os itens dos nós
# filhos.
# - Heap máximo: pai >= filhos
# - Heap mínimo: pai <= filhos
# - Forma: árvore binária tem que ser completa
# até o penúltimo nível, sendo que no último
# nível os nós têm que estar agrupados à
# esquerda.

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-35-20.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-34-58.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-36-16.png](data:image/png;base64,...)

# %% [markdown]
# A estrutura heap pode ser usada para ordenar
# um vetor.
# - Construir um heap máximo
# - Trocar a raíz (maior elemento) com o
# elemento da última posição do vetor
# - Diminuir o tamanho do heap em 1
# - Rearranjar o heap máximo (agora com n-1
# elementos), se necessário
# - Repetir o processo n-1 vezes.

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-36-45.png](data:image/png;base64,...)

# %% [markdown]
# O processo termina até todos os elementos
# terem sido incluídos no vetor de forma
# ordenada.
#
# É necessário:
# - Saber construir um heap a partir de um vetor
# qualquer.
# - Saber como rearranjar o heap, i.e., manter a
# propriedade do heap máximo.

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-40-15.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-40-29.png](data:image/png;base64,...)

# %% [markdown]
# A construção do heap envolve chamar o
# procedimento rearranjar heap de forma
# ascendente para os n/2 – 1 nós da árvore (nós
# não folha).
#
# Com isso, ao chamar pela última vez o
# procedimento para a raíz, teremos o heap
# máximo construído.

# %% [markdown]
# > Bloco com recuo![Captura de tela de 2020-11-04 15-41-15.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-42-03.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-42-13.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de tela de 2020-11-04 15-42-24.png](data:image/png;base64,...)

# %% [markdown]
# ## Busca

# %% [markdown]
# ## Exercicios de Apoio
